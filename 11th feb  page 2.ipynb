# %%
import pandas as pd

# %%
rev = pd.read_csv("revenue.csv",index_col="Date")

# %%
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
rev.sum(axis=1)
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# # select one column from data frame

# %%
import pandas as pd

# %%
nba=pd.read_csv("nba.csv")

# %%
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.Salary
# Out:
# 0       7730337.0
# 1       6796117.0
# 2             NaN
# 3       1148640.0
# 4       5000000.0
# 5      12000000.0
# 6       1170960.0
# 7       2165160.0
# 8       1824360.0
# 9       3431040.0
# 10      2569260.0
# 11      6912869.0
# 12      3425510.0
# 13      1749840.0
# 14      2616975.0
# 15      3425510.0
# 16       845059.0
# 17      1500000.0
# 18      1335480.0
# 19      6300000.0
# 20      1599840.0
# 21       134215.0
# 22      1500000.0
# 23     19689000.0
# 24      1140240.0
# 25       947276.0
# 26       981348.0
# 27       947276.0
# 28       947276.0
# 29     11235955.0
#           ...
# 428     8042895.0
# 429      625093.0
# 430      947276.0
# 431     6980802.0
# 432     2894059.0
# 433     6000000.0
# 434     5016000.0
# 435     3075880.0
# 436     4236287.0
# 437     2525160.0
# 438      525093.0
# 439     1415520.0
# 440     2854940.0
# 441     2637720.0
# 442     4775000.0
# 443     2658240.0
# 444     9463484.0
# 445     3777720.0
# 446    12000000.0
# ...

# %%
type(nba["Name"])
# Out:
# pandas.core.series.Series

# %%
nba.Salary
nba.Number
nba.Name
# Out:
# 0                Avery Bradley
# 1                  Jae Crowder
# 2                 John Holland
# 3                  R.J. Hunter
# 4                Jonas Jerebko
# 5                 Amir Johnson
# 6                Jordan Mickey
# 7                 Kelly Olynyk
# 8                 Terry Rozier
# 9                 Marcus Smart
# 10             Jared Sullinger
# 11               Isaiah Thomas
# 12                 Evan Turner
# 13                 James Young
# 14                Tyler Zeller
# 15            Bojan Bogdanovic
# 16                Markel Brown
# 17             Wayne Ellington
# 18     Rondae Hollis-Jefferson
# 19                Jarrett Jack
# 20              Sergey Karasev
# 21             Sean Kilpatrick
# 22                Shane Larkin
# 23                 Brook Lopez
# 24            Chris McCullough
# 25                 Willie Reed
# 26             Thomas Robinson
# 27                  Henry Sims
# 28                Donald Sloan
# 29              Thaddeus Young
# ...

# %%
nba[["Name","Team"]]
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       sport
# 0              Texas  7730337.0  Backetball
# 1          Marquette  6796117.0  Backetball
# 2  Boston University        NaN  Backetball
# 3      Georgia State  1148640.0  Backetball
# 4                NaN  5000000.0  Backetball

# %%
select=["salary","name","Team"]

# %%
nba[select]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-17e709629c04> in <module>
# ----> 1 nba[select]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2922                 key = list(key)
#    2923             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2924                                                    raise_missing=True)
#    2925
#    2926         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ...

# %% [markdown]
# # add new column to data frame

# %%
import pandas as pd

# %%
nba["sport"]="Backetball"

# %%
nba.head(5)
# Out:
#             Name            Team  Number    games Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  cricket       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  cricket       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  cricket       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  cricket       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  cricket       PF  29.0   6-10
#
#    Weight            College     Salary       sport
# 0   180.0              Texas  7730337.0  Backetball
# 1   235.0          Marquette  6796117.0  Backetball
# 2   205.0  Boston University        NaN  Backetball
# 3   185.0      Georgia State  1148640.0  Backetball
# 4   231.0                NaN  5000000.0  Backetball

# %%
nba.insert(3,column="games",value="cricket")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-5d8408193806> in <module>
# ----> 1 nba.insert(3,column="games",value="cricket")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3461         value = self._sanitize_column(column, value, broadcast=False)
#    3462         self._data.insert(loc, column, value,
# -> 3463                           allow_duplicates=allow_duplicates)
#    3464
#    3465     def assign(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
# ...

# %% [markdown]
# nba.head(6)

# %%
nba.insert(6,football="games",value="chess")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-d05dda028e37> in <module>
# ----> 1 nba.insert(6,column="games",value="cricket")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3461         value = self._sanitize_column(column, value, broadcast=False)
#    3462         self._data.insert(loc, column, value,
# -> 3463                           allow_duplicates=allow_duplicates)
#    3464
#    3465     def assign(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
# ...

# %% [markdown]
# # broad casting operation

# %%
import pandas as pd
