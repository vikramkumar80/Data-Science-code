# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Gender"] == "Female"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12     False
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 970     True
# 971    False
# 972    False
# 973    False
# 974    False
# 975     True
# 976     True
# 977     True
# 978    False
# 979    False
# 980     True
# 981    False
# 982     True
# 983    False
# 984     True
# 985    False
# 986     True
# 987     True
# 988     True
# 989    False
# 990     True
# 991     True
# 992    False
# 993     True
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %%
df["Team"] == "Team=”Engineering”, “Distribution” or “Finance”"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
import pandas as pd
nba = pd.read_csv("nba.csv",index_col = "Team")

# %%
nba.head()
# Out:
#                          Name  Number Position   Age Height  Weight  \
# Team
# Boston Celtics  Avery Bradley     0.0       PG  25.0    6-2   180.0
# Boston Celtics    Jae Crowder    99.0       SF  25.0    6-6   235.0
# Boston Celtics   John Holland    30.0       SG  27.0    6-5   205.0
# Boston Celtics    R.J. Hunter    28.0       SG  22.0    6-5   185.0
# Boston Celtics  Jonas Jerebko     8.0       PF  29.0   6-10   231.0
#
#                           College     Salary
# Team
# Boston Celtics              Texas  7730337.0
# Boston Celtics          Marquette  6796117.0
# Boston Celtics  Boston University        NaN
# Boston Celtics      Georgia State  1148640.0
# Boston Celtics                NaN  5000000.0

# %%
nba.loc[["Boston Celtics"]].head()
# Out:
#                          Name  Number Position   Age Height  Weight  \
# Team
# Boston Celtics  Avery Bradley     0.0       PG  25.0    6-2   180.0
# Boston Celtics    Jae Crowder    99.0       SF  25.0    6-6   235.0
# Boston Celtics   John Holland    30.0       SG  27.0    6-5   205.0
# Boston Celtics    R.J. Hunter    28.0       SG  22.0    6-5   185.0
# Boston Celtics  Jonas Jerebko     8.0       PF  29.0   6-10   231.0
#
#                           College     Salary
# Team
# Boston Celtics              Texas  7730337.0
# Boston Celtics          Marquette  6796117.0
# Boston Celtics  Boston University        NaN
# Boston Celtics      Georgia State  1148640.0
# Boston Celtics                NaN  5000000.0

# %%
df = pd.read_csv("employees.csv")
df.head(7)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female  8/17/1987         4:20 PM   65476   10.012
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal
# 6              True          Product

# %%
df.dropna(how = "all",axis=1)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 10      Louise  Female   8/12/1980         9:01 AM   63241   15.132
# 11       Julie  Female  10/26/1997         3:19 PM  102508   12.637
# 12     Brandon    Male   12/1/1980         1:08 AM  112807   17.492
# ...

# %%
df = pd.read_csv("employees.csv")
df.head(7)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female  8/17/1987         4:20 PM   65476   10.012
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal
# 6              True          Product

# %%
len(df)
# Out:
# 1000

# %%
df.loc[1001] = [df["First Name"][440], 
                  df["Gender"][440], 
                  df["Start Date"][440], 
                  df["Last Login Time"][440], 
                  df["Salary"][440], 
                  df["Bonus %"][440], 
                  df["Senior Management"][440], 
                  df["Team"][440]]

# %%
len(df)
# Out:
# 1001

# %%
df.sort_values("First Name").head()
# Out:
#      First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 1001      Aaron   Male  7/22/1990         2:53 PM   52119   11.343
# 327       Aaron   Male  1/29/1994         6:48 PM   58755    5.097
# 440       Aaron   Male  7/22/1990         2:53 PM   52119   11.343
# 937       Aaron    NaN  1/22/1986         7:39 PM   63126   18.424
# 101       Aaron   Male  2/17/2012        10:20 AM   61602   11.849
#
#      Senior Management             Team
# 1001              True  Client Services
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 101               True        Marketing
