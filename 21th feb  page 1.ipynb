# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv",parse_dates=["Start Date","Last Login Time"])
df.head(5)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-02-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-02-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-02-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.7+ KB

# %%
df[Senior Management"] = df["Senior Management"].astype("bool")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.7+ KB

# %%
df["Team"] = df["Team"].astype("bool")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 1000 non-null bool
# dtypes: bool(2), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 48.9+ KB

# %% [markdown]
# # filter a dataframe based  on condition

# %%
df[df["Gender"] == "Male"].head(5)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2019-02-21 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2019-02-21 06:53:00   61933    4.170
# 3      Jerry   Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry   Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
# 5     Dennis   Male 1987-04-18 2019-02-21 01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
antman = df[df["Team"] == "Finance"].head(5)

# %%
antman
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2019-02-21 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2019-02-21 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2019-02-21 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2019-02-21 22:47:00  114796    6.796
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance

# %%
df[df["Salary"] >11000].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-02-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-02-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-02-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Bonus %"]<2.0].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4       Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
# 15    Lillian  Female 2016-06-05 2019-02-21 06:09:00   59414    1.256
# 19      Donna  Female 2010-07-22 2019-02-21 03:48:00   81014    1.894
# 52       Todd    Male 1990-02-18 2019-02-21 02:41:00   49339    1.695
# 58    Theresa  Female 2010-04-11 2019-02-21 07:18:00   72670    1.481
#
#     Senior Management             Team
# 4                True  Client Services
# 15              False          Product
# 19              False          Product
# 52               True  Human Resources
# 58               True      Engineering

# %%
df[df["Start Date"] >= "1998-01-24"].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3      Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
# 7        NaN  Female 2015-07-20 2019-02-21 10:43:00   45906   11.598
# 8     Angela  Female 2005-11-22 2019-02-21 06:29:00   95570   18.523
# 9    Frances  Female 2002-08-08 2019-02-21 06:51:00  139852    7.524
#
#    Senior Management                  Team
# 3               True               Finance
# 4               True       Client Services
# 7               True               Finance
# 8               True           Engineering
# 9               True  Business Development

# %%
df["Gender"] =df["Gender"].astype("category")
df.head(5)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-02-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-02-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-02-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
#
#    Senior Management  Team
# 0               True  True
# 1               True  True
# 2              False  True
# 3               True  True
# 4               True  True

# %%
mask1 = df ["Gender"] == "male"
mask2 = df["Team"]=="Finance"

# %%
df[~mask1 & ~mask2].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2019-02-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2019-02-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2019-02-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2019-02-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2019-02-21 16:47:00  101004    1.389
#
#    Senior Management  Team
# 0               True  True
# 1               True  True
# 2              False  True
# 3               True  True
# 4               True  True
